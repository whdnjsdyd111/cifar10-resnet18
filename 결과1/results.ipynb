# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import matplotlib as mpl

# %%
test = "epoch-%d lr-%.4f batch-128 model_num3-0 acc.png" % (50, 0.0050)
test = img.imread(test)
test = test[57:449, 54:578]
plt.axis('off')
plt.imshow(test)

# %%
imgs = []

for lr in [0.0050, 0.0100]:
    for epoch in [50, 60, 70]:
        path = "epoch-%d lr-%.4f batch-128 model_num3-0 acc.png" % (epoch, lr)
        acc_png = img.imread(path)
        acc_png = acc_png[57:449, 45:578]
        imgs.append(acc_png)

# %%
fig = plt.figure(dpi=500)
rows = 2
cols = 3
i = 1

for lr in [0.005, 0.01]:
    for epoch in [50, 60, 70]:
        ax = fig.add_subplot(rows, cols, i)
        ax.imshow(imgs[i - 1])
        ax.set_title("epoch-%d lr-%.3f" % (epoch, lr))
        ax.axis("off")
        i += 1
        
# plt.subplots(constrained_layout=True)
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 6
plt.subplots_adjust(wspace=0, hspace=-0.3)
plt.show()
